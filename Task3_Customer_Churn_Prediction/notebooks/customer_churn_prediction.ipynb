# %% [markdown]
# # Customer Churn Prediction
#
# This notebook is a lightweight project companion. The production workflow lives in `src/train.py` and the Streamlit interface lives in `app.py`.

# %%
from pathlib import Path
import pandas as pd

dataset_path = Path('../dataset/Churn_Modelling.csv')
df = pd.read_csv(dataset_path)
df.head()

# %%
df.info()
df['Exited'].value_counts(normalize=True)
